# %% [markdown]
# # Relatório de Analise I

# %%
import pandas as pd

# %%
df = pd.read_csv('aluguel.csv', sep = ';')

# %%
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites
# 0                    Quitinete            Copacabana        1      0       0  \
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
df.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area
# 0                Quitinete       Copacabana        1      0       0    40  \
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# ## Informações Gerais sobre a base

# %%
df.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipo_dados = pd.DataFrame(df.dtypes, columns = ['Tipo de Dados'])

# %%
tipo_dados.columns.name = 'Variavel'

# %%
tipo_dados
# Out:
# Variavel   Tipo de Dados
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64

# %%
df.shape
# Out:
# (32960, 9)

# %%
print('A base de dados apresenta {} registros (imoveis) e {} variaveis'.format(df.shape[0], df.shape[1]))
# Out:
# A base de dados apresenta 32960 registros (imoveis) e 9 variaveis

# %% [markdown]
# ## Importando dados via Json

# %%
import pandas as pd

json = open(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.json')

# %%
df_json
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area
# 0                Quitinete       Copacabana        1      0       0    40  \
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
txt = open(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.json')

# %%
df_html = pd.read_html(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\dados_html_1.html')
df_html
# Out:
# [  FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
#  0      00 A 18               R$218,99           R$192,60    R$334,48
#  1      19 A 23               R$263,63           R$207,67    R$380,06
#  2      24 A 28               R$322,44           R$224,26    R$464,39
#  3      29 A 33               R$402,05           R$258,63    R$566,68
#  4      34 A 38               R$455,17           R$306,37    R$664,61
#  5      39 A 43               R$489,29           R$417,93    R$742,72
#  6      44 A 48               R$582,65           R$495,24    R$869,47
#  7      49 A 53               R$718,86           R$562,64  R$1.046,29
#  8      54 A 58               R$908,54           R$721,00  R$1.355,74
#  9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53]

# %% [markdown]
# # Relatório de Analise II

# %% [markdown]
# ### Tipos de imoveis

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.csv', sep=';')
df
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0      Apartamento               Centro        1      0       0    15   800.0  \
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
df.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento                   Centro        1      0       0    15   800.0  \
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
df['Tipo']
# Out:
# 0        Apartamento
# 1        Apartamento
# 2        Apartamento
# 3        Apartamento
# 4        Apartamento
#             ...
# 19826      Quitinete
# 19827      Quitinete
# 19828      Quitinete
# 19829      Quitinete
# 19830      Quitinete
# Name: Tipo, Length: 19831, dtype: object

# %%
df.Tipo
# Out:
# 0        Apartamento
# 1        Apartamento
# 2        Apartamento
# 3        Apartamento
# 4        Apartamento
#             ...
# 19826      Quitinete
# 19827      Quitinete
# 19828      Quitinete
# 19829      Quitinete
# 19830      Quitinete
# Name: Tipo, Length: 19831, dtype: object

# %%
tipo_de_imovel = df['Tipo']

# %%
tipo_de_imovel.drop_duplicates(inplace=True)

# %%
tipo_de_imovel
# Out:
# 0               Apartamento
# 16923                  Casa
# 17821    Casa de Condomínio
# 18785          Casa de Vila
# 19018             Quitinete
# Name: Tipo, dtype: object

# %% [markdown]
# ## Organizando a Visualização

# %%
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)

# %%
tipo_de_imovel.index
# Out:
# Index([0, 16923, 17821, 18785, 19018], dtype='int64')

# %%
tipo_de_imovel.shape[0]
# Out:
# 5

# %%
range(tipo_de_imovel.shape[0])
# Out:
# range(0, 5)

# %%
for i in range(tipo_de_imovel.shape[0]):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])

# %%
tipo_de_imovel.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
tipo_de_imovel
# Out:
#                  Tipo
# 0         Apartamento
# 1                Casa
# 2  Casa de Condomínio
# 3        Casa de Vila
# 4           Quitinete

# %% [markdown]
# # Relatório de Analise III

# %% [markdown]
# ## Imoveis Residenciais

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.csv', sep=';')
df
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0      Apartamento               Centro        1      0       0    15   800.0  \
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
df.head()
# Out:
#           Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento               Centro        1      0       0    15   800.0  \
# 1  Apartamento         Higienópolis        1      0       0    48   800.0
# 2  Apartamento             Cachambi        2      0       0    50  1300.0
# 3  Apartamento               Grajaú        2      1       0    70  1500.0
# 4  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       390.0  20.0     53.33   Apartamento
# 1       230.0   0.0     16.67   Apartamento
# 2       301.0  17.0     26.00   Apartamento
# 3       642.0  74.0     21.43   Apartamento
# 4       455.0  14.0     16.67   Apartamento

# %%
list(df['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial = ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
selecao = df['Tipo'].isin(residencial)
selecao
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 19826    True
# 19827    True
# 19828    True
# 19829    True
# 19830    True
# Name: Tipo, Length: 19831, dtype: bool

# %%
df_residencial = df[selecao]

# %%
df_residencial
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0      Apartamento               Centro        1      0       0    15   800.0  \
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %% [markdown]
# # Relatório de Análise IV
# ## Seleção e Frequências

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.csv', sep=';')
df.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento                   Centro        1      0       0    15   800.0  \
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
#Selecione somente os imóveis classificados com tipo 'Apartamento'.
selecao = df['Tipo'] == 'Apartamento'
n1 = df[selecao].shape[0]
n1
# Out:
# 16923

# %%
#Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'.
selecao = (df['Tipo'] == 'Casa') | (df['Tipo'] == 'Casa de Condomínio') | (df['Tipo'] == 'Casa de Vila')
n2 = df[selecao].shape[0]
n2
# Out:
# 2095

# %%
#Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
selecao = (df['Area'] >= 60) & (df['Area'] <= 100)
n3 = df[selecao].shape[0]
n3
# Out:
# 8362

# %%
#Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.
selecao = (df['Quartos'] >= 4 ) & (df['Valor'] < 2000 ) 
n4 = df[selecao].shape[0]
n4
# Out:
# 36

# %%
print(f''' 
Nº de imóveis classificados com tipo 'Apartamento'. -> {n1}
Nº de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'. -> {n2}
Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites. -> {n3}
Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00. -> {n4}
''')
# Out:
#
# Nº de imóveis classificados com tipo 'Apartamento'. -> 16923
# Nº de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'. -> 2095
# Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites. -> 8362
# Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00. -> 36

# %%
data = [(1, 2, 3, 4),
        (5, 6, 7, 8),
        (8, 10, 11, 12),
        (13, 14, 15, 16)]
df = pd.DataFrame(data, 'l1 l2 l3 l4'.split(), 'c1 c2 c3 c4'.split())

# %%
df[['c1', 'c3']]
# Out:
#     c1  c3
# l1   1   3
# l2   5   7
# l3   8  11
# l4  13  15

# %% [markdown]
# # Tratando Dados Faltantes

# %%
df[df['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
selecao = (df['Tipo'] == 'Apartamento') & (df['Condominio'].isnull())

# %% [markdown]
# # Relatório de Análise IV
# ## Criando novas Variaveis

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.csv', sep=';')
df.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento                   Centro        1      0       0    15   800.0  \
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
df.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento                   Centro        1      0       0    15   800.0  \
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU   Valor m2 Tipo Agregado  Valor_Bruto
# ...

# %%
df['Valor_Bruto'] = df['Valor'] + df['Condominio'] + df['IPTU']

# %%
df['Valor m2'] = df['Valor'] /  df['Area']

# %%
df.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor
# 0  Apartamento                   Centro        1      0       0    15   800.0  \
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU   Valor m2 Tipo Agregado  Valor_Bruto
# ...

# %%
df['Valor m2'] = df['Valor m2'].round(2)

# %%
df['Valor Bruto m2'] = (df['Valor_Bruto'] /  df['Area']).round(2)

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']
df['Tipo Agregado'] = df['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')
df
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0      Apartamento               Centro        1      0       0    15   800.0  \
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %% [markdown]
# ## Excluindo Variaveis

# %%
df_aux = pd.DataFrame(df[['Tipo Agregado', 'Valor m2', 'Valor_Bruto', 'Valor Bruto m2']])

# %%
df_aux.pop('Valor Bruto m2')
# Out:
# 0        80.67
# 1        21.46
# 2        32.36
# 3        31.66
# 4        21.88
#          ...
# 19826    51.70
# 19827    65.43
# 19828    59.29
# 19829    90.27
# 19830    43.52
# Name: Valor Bruto m2, Length: 19831, dtype: float64

# %%
df.drop(['Valor_Bruto', 'Valor Bruto m2'], axis = 1, inplace=True)

# %%
df
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor
# 0      Apartamento               Centro        1      0       0    15   800.0  \
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %% [markdown]
# # R

# %%
df = pd.read_csv(r'C:\Users\eldiniz\OneDrive - Stefanini\Documents\Cursos\Alura\Python_Pandas_tratando_analisando_dados\dados\aluguel.csv', sep=';')

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = df['Bairro'].isin(bairros)
df = df[selecao]

# %%
df['Bairro'].drop_duplicates()
# Out:
# 5           Copacabana
# 7      Barra da Tijuca
# 8               Tijuca
# 11             Ipanema
# 14            Botafogo
# 17              Leblon
# 105           Flamengo
# Name: Bairro, dtype: object

# %%
grupo_bairro = df.groupby('Bairro')

# %%
for bairro, dados in grupo_bairro: 
    print(bairro)
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
for bairro, dados in grupo_bairro: 
    print('{} -> {}'.format(bairro, dados.Valor.mean()))
# Out:
# Barra da Tijuca -> 5500.497783032811
# Botafogo -> 3375.4605418138985
# Copacabana -> 3351.519427402863
# Flamengo -> 3220.119266055046
# Ipanema -> 5451.549307253464
# Leblon -> 5661.45393258427
# Tijuca -> 1999.9380127620784

# %%
grupo_bairro['Valor'].mean()
# Out:
# Bairro
# Barra da Tijuca    5500.497783
# Botafogo           3375.460542
# Copacabana         3351.519427
# Flamengo           3220.119266
# Ipanema            5451.549307
# Leblon             5661.453933
# Tijuca             1999.938013
# Name: Valor, dtype: float64

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  5500.50     3588.23
# Botafogo         3375.46      939.98
# Copacabana       3351.52     1039.22
# Flamengo         3220.12      933.88
# Ipanema          5451.55     1674.58
# Leblon           5661.45     1617.80
# Tijuca           1999.94      713.43

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean      std     min     25%     50%     75%
# Bairro
# Barra da Tijuca  3383.0  5500.50  5123.02   800.0  2400.0  3700.0  6700.0  \
# Botafogo          849.0  3375.46  2015.90   700.0  2200.0  3000.0  4250.0
# Copacabana       2445.0  3351.52  1904.58   100.0  1915.0  2900.0  4200.0
# Flamengo          654.0  3220.12  1958.30   800.0  1800.0  2700.0  4000.0
# Ipanema          1227.0  5451.55  2093.76  1200.0  3759.0  5500.0  7000.0
# Leblon            890.0  5661.45  2746.71   100.0  3900.0  5000.0  7000.0
# Tijuca           1097.0  1999.94  1039.67   750.0  1500.0  1800.0  2300.0
#
#                      max
# Bairro
# Barra da Tijuca  32000.0
# Botafogo         22000.0
# Copacabana        9900.0
# Flamengo          9500.0
# Ipanema           9900.0
# Leblon           30000.0
# Tijuca           19000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum'])
# Out:
#                     min      max         sum
# Bairro
# Barra da Tijuca   800.0  32000.0  18608184.0
# Botafogo          700.0  22000.0   2865766.0
# Copacabana        100.0   9900.0   8194465.0
# Flamengo          800.0   9500.0   2105958.0
# Ipanema          1200.0   9900.0   6689051.0
# Leblon            100.0  30000.0   5038694.0
# Tijuca            750.0  19000.0   2193932.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo   Máximo         sum
# Bairro
# Barra da Tijuca   800.0  32000.0  18608184.0
# Botafogo          700.0  22000.0   2865766.0
# Copacabana        100.0   9900.0   8194465.0
# Flamengo          800.0   9500.0   2105958.0
# Ipanema          1200.0   9900.0   6689051.0
# Leblon            100.0  30000.0   5038694.0
# Tijuca            750.0  19000.0   2193932.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
fig = grupo_bairro['Valor'].std().plot.bar()
fig.set_ylabel('Valor Aluguel')
fig.set_title('Valor médio aluguel', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor médio aluguel')
